# %% [markdown]
# VECINDARIO TORONTO PARTE 2

# %%
import pandas as pd
import numpy as np
# !pip install geocoder
import geocoder
# !pip install wget
import wget
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting geocoder
#   Downloading geocoder-1.38.1-py2.py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 2.2 MB/s
# Collecting ratelim
#   Downloading ratelim-0.1.6-py2.py3-none-any.whl (4.0 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from geocoder) (7.1.2)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from geocoder) (0.16.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from geocoder) (2.23.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from geocoder) (1.15.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ratelim->geocoder) (4.4.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->geocoder) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->geocoder) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->geocoder) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->geocoder) (3.0.4)
# Installing collected packages: ratelim, geocoder
# Successfully installed geocoder-1.38.1 ratelim-0.1.6
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9675 sha256=94897381e8e814acde8e6622a4ae4bd81e6b533818f8967565e060f33519931e
#   Stored in directory: /root/.cache/pip/wheels/a1/b6/7c/0e63e34eb06634181c63adacca38b79ff8f35c37e3c13e3c02
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2

# %%
# Importamos el dataframe de la primera parte
df = pd.read_html('https://en.wikipedia.org/w/index.php?title=List_of_postal_codes_of_Canada:_M&oldid=1008658788')
df_code_toronto = df[0]
df_code_toronto = df_code_toronto[df_code_toronto['Borough']!= 'Not assigned']
df_code_toronto = df_code_toronto.reset_index(drop=True)
df_code_toronto.head(12)
# Out:
#    Postal Code           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 3          M6A        North York
# 4          M7A  Downtown Toronto
# 5          M9A         Etobicoke
# 6          M1B       Scarborough
# 7          M3B        North York
# 8          M4B         East York
# 9          M5B  Downtown Toronto
# 10         M6B        North York
# 11         M9B         Etobicoke
#
#                                         Neighbourhood
# 0                                           Parkwoods
# 1                                    Victoria Village
# 2                           Regent Park, Harbourfront
# 3                    Lawrence Manor, Lawrence Heights
# 4         Queen's Park, Ontario Provincial Government
# 5             Islington Avenue, Humber Valley Village
# 6                                      Malvern, Rouge
# 7                                           Don Mills
# 8                     Parkview Hill, Woodbine Gardens
# 9                            Garden District, Ryerson
# 10                                          Glencairn
# 11  West Deane Park, Princess Gardens, Martin Grov...

# %%
#Datos a buscar
postal_code=df_code_toronto["Postal Code"]
postal_code
# Out:
# 0      M3A
# 1      M4A
# 2      M5A
# 3      M6A
# 4      M7A
#       ...
# 98     M8X
# 99     M4Y
# 100    M7Y
# 101    M8Y
# 102    M8Z
# Name: Postal Code, Length: 103, dtype: object

# %%
g = geocoder.google('M3A, Toronto, Ontario')
g.latlng
print('Toronto, Ontario Postal code M3A',g.latlng)
# Out:
# Toronto, Ontario Postal code M3A None

# %%
# !wget -O toronto_coord.csv http://cocl.us/Geospatial_data 
df_toronto_coord = pd.read_csv('toronto_coord.csv')
print(df_toronto_coord.head())
print(df_toronto_coord.shape)
# Out:
# --2022-07-02 23:31:55--  http://cocl.us/Geospatial_data
# Resolving cocl.us (cocl.us)... 184.51.102.17, 184.51.102.82, 2600:140e:6::b833:66ca, ...
# Connecting to cocl.us (cocl.us)|184.51.102.17|:80... connected.
# HTTP request sent, awaiting response... 308 Permanent Redirect
# Location: https://cocl.us/geospatial_data [following]
# --2022-07-02 23:31:57--  https://cocl.us/geospatial_data
# Connecting to cocl.us (cocl.us)|184.51.102.17|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2022-07-02 23:31:58--  https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.box.com (ibm.box.com)... 107.152.24.197
# Connecting to ibm.box.com (ibm.box.com)|107.152.24.197|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2022-07-02 23:31:59--  https://ibm.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Reusing existing connection to ibm.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2022-07-02 23:31:59--  https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.ent.box.com (ibm.ent.box.com)... 103.116.4.201
# Connecting to ibm.ent.box.com (ibm.ent.box.com)|103.116.4.201|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://dl2.boxcloud.com/d/1/b1!a6HlX6n_zOFrAURGU6m1CXCoUZaOhXAcfzCsq3rnha5K7kFOWJDZS7hQnSERj6n5mBHAcgx-xiLPQSbLCE6CmXIi8T6v05M-Xcs7uhIU7v41E7p7ZUjn_VU9lwZb1zeKxfXOjS5bQKvsL4WVahFZ1_WIFZns2BXk9Sz2oH2oOq1fIR28HJC78plb0EnSme34fnlaF4y2hjM1jaiN8U7DWiuYZCYgAggG7oXzLJwv_YMGJfwCGvVHQIwcUNfHMJcwzLdpfe85DlfqbgxiAislKm5ThucUm27-rphUdEOfRS1Gg3P3X1pueZby2NGw2YmsETh1rTScSaZD0aIWfadqnVfA1pPs9v4VRFvdsfxdRwtM5FwsPZTD7md37ms2tlrGjxC0oKfAVarn_b7o7M9nb02W0jWqABQKnzkPYACqfclIoYTucAxI3ALqzWNdWdpCfq2uurDYEQvYMDVSEGpDik__AxZXT3NlmoyDt_RgRd7I83e8OJ6W8nKgEoppygPOE_4fZI4z2IZWdOApUCtTiwU8Wvfx79e1xBr1HgT80gqG0DAiLHSh8HPTXCNL8_EpRuHKDYp65THn4XhSZH4tXshN9qW5qNALfu0prVNhXeUD83wEr2u97QUjra7uTjHe4DAe9ryoCTDjhAKWK3ptz0TMlAhb3FrAs5BlCQEqTp102OvyY6SweKjRmcLPvBHeDY1WHgf13snzZnivm1rm5U4slj5-qXZWBbFTqy4-vllH7UG5GFdmXK37QKTbOv_MNrwJ1gQTl4yOm6wDQ6nqOKJdl0cIQRv57JxOJE06IJ_BSSkOx_wkNKY1PVO8JHO88YYtFT7a8s4w8r-lMjNxLm1dYFXChqxYRmJPsf_pVHYeXu7XCDrGU5s0cdOWfCOaS_aT47i_fMO_4G1Bi6hkSTgccgAq2Mo7OHcp1QoCj_8qbriSCYvIlY6hRtNdf5MxWyqCq3iVKR6AXUHo2bhEGUZQE-joGZuW4P73jf9voKsLOSyjwMDe7m7Etta-RAAkm5MQDPRVJ80VqG6OatnpDpLljwuyHcC2qykOFwkBss6ZGkZTz4FN_EEYfRfTjK-EdGWMYGp-_x3ffGRxP_N4HEXPb7IWZ2Cv5Pre5dqYopRUgVUmDfFeRe